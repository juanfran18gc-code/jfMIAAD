# %% [markdown]
# <a href="https://colab.research.google.com/github/juanfran18gc-code/jfMIAAD/blob/06-Semana/Practica18_261554.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Autor: Juan Francisco Gámez Cortés.
# Matricula: 261554
#
# Última Modificación: 17 de septiembre de 2025
#
# # Práctica #18: Datos Temporales
# # Objetivo:
# El objetivo de esta actividad es que los estudiantes practiquen los temas vistos de limpieza y transformación de datos categóricos.

# %% [markdown]
# #Instrucciones:
#
# 1.  Descarga el archivo airdata.csv, proporcionado en esta tarea. También lo puedes encontrar en recursos.
# 2.  Crea un notebook en colab y guarda el archivo csv  en tu drive.
# 3.  Agrega secciones en el colab poniendo como título el nombre de cada ejercicio

# %%
#MontarGoogle Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #Ejercicio 01: Tipo de Datos Correcto
# 1.  Carga el conjunto de datos airdata.csv y verifica que cada columna tenga el tipo de datos correcto
# 2.  Si una columna de tipo temporal no está en el tipo de correcto realiza la conversión.
# 3.  Usa dtypes para mostrar que cada columna, principalmente la que contiene datos temporales, está en el tipo de datos correcto
# 4.  Imprime las primeras tres líneas

# %%
import pandas as pd
#Cargar el dataset
df= pd.read_csv('/content/drive/MyDrive/Unidad02/Airdata.csv')

#Observar las columnas y datos del dataframe así como los tipos de datos
print(df.head())
print(df.dtypes)
# Out:
#         DateTime  Temperature  Humidity  Wind_Speed  Wind_Direction  \
# 0  1/1/2020 0:00     2.180529        87    1.484318       75.963760
# 1  1/1/2020 1:00     1.490529        89    2.741678      113.198590
# 2  1/1/2020 2:00     1.690529        85    3.563818      135.000000
# 3  1/1/2020 3:00     1.430529        84    2.811690      129.805570
# 4  1/1/2020 4:00     0.840529        86    1.800000      126.869896
#
#    NO2_Location_A  NO2_Location_B  NO2_Location_C
# 0           39.23           52.88           62.37
# 1           38.30           44.95           52.53
# 2             NaN           48.40           54.80
# 3           37.28           47.18           50.80
# 4           29.97           41.48           54.43
# DateTime           object
# Temperature       float64
# Humidity            int64
# Wind_Speed        float64
# Wind_Direction    float64
# NO2_Location_A    float64
# NO2_Location_B    float64
# NO2_Location_C    float64
# dtype: object

# %%
#Convertir columna DateTime en tipo de datos datetime
df['DateTime'] = pd.to_datetime(df['DateTime'])

# %%
#Imprimir el tipo de datos de las columnas, así como las tres primeras líneas
print(df.dtypes)
print(df.head(3))
# Out:
# DateTime          datetime64[ns]
# Temperature              float64
# Humidity                   int64
# Wind_Speed               float64
# Wind_Direction           float64
# NO2_Location_A           float64
# NO2_Location_B           float64
# NO2_Location_C           float64
# dtype: object
#              DateTime  Temperature  Humidity  Wind_Speed  Wind_Direction  \
# 0 2020-01-01 00:00:00     2.180529        87    1.484318        75.96376
# 1 2020-01-01 01:00:00     1.490529        89    2.741678       113.19859
# 2 2020-01-01 02:00:00     1.690529        85    3.563818       135.00000
#
#    NO2_Location_A  NO2_Location_B  NO2_Location_C
# 0           39.23           52.88           62.37
# 1           38.30           44.95           52.53
# 2             NaN           48.40           54.80

# %% [markdown]
# #Ejercicio 02: Extraer componentes de fecha y tiempo
#
# 1.  De la columna 'DateTime' extrae el año, mes, día y hora. Crea una nueva columna para cada componente que extraes
# 2.  Imprime las primeras tres líneas del dataframe que ahora deberá tener 4 nuevas columnas.

# %%
#Extraer año, mes, día y hora de la columna que contiene la fecha para crear nuevas columnas
df['Año'] = df['DateTime'].dt.year
df['Mes'] = df['DateTime'].dt.month
df['Dia'] = df['DateTime'].dt.day
df['Hora'] = df['DateTime'].dt.hour

#Validar que el dataframe contiene las 4 nuevas columnas
print(df.head(3))
#print(df.dtypes)
# Out:
#              DateTime  Temperature  Humidity  Wind_Speed  Wind_Direction  \
# 0 2020-01-01 00:00:00     2.180529        87    1.484318        75.96376
# 1 2020-01-01 01:00:00     1.490529        89    2.741678       113.19859
# 2 2020-01-01 02:00:00     1.690529        85    3.563818       135.00000
#
#    NO2_Location_A  NO2_Location_B  NO2_Location_C   Año  Mes  Dia  Hora
# 0           39.23           52.88           62.37  2020    1    1     0
# 1           38.30           44.95           52.53  2020    1    1     1
# 2             NaN           48.40           54.80  2020    1    1     2

# %% [markdown]
# #Ejercicio 03: Aritmética - Suma de Intervalos (timedelta)
#
# * Suma 10 días, 7 horas y 15 minutos a cada elemento de la columna 'DateTime'. Guarda el resultado en una nueva columna y agrega al dataframe.
# * Imprime la columna 'DateTime' y la columna que resulta de sumar 10 días, 7 horas y 15 minutos.

# %%
#Sumar intervalo a los elementos del df para crear la nueva columna
df['FechaIntervalo'] = df['DateTime'] + pd.Timedelta(days=10, hours= 7, minutes=15)

#Imrpmir las columnas para observar la fecha original y la fecha con el intervalo
print(f'Fecha original:',df['DateTime'])
print(f'Fecha con intervalo:',df['FechaIntervalo'])
# Out:
# Fecha original: 0      2020-01-01 00:00:00
# 1      2020-01-01 01:00:00
# 2      2020-01-01 02:00:00
# 3      2020-01-01 03:00:00
# 4      2020-01-01 04:00:00
#                ...
# 8779   2020-12-31 19:00:00
# 8780   2020-12-31 20:00:00
# 8781   2020-12-31 21:00:00
# 8782   2020-12-31 22:00:00
# 8783   2020-12-31 23:00:00
# Name: DateTime, Length: 8784, dtype: datetime64[ns]
# Fecha con intervalo: 0      2020-01-11 07:15:00
# 1      2020-01-11 08:15:00
# 2      2020-01-11 09:15:00
# 3      2020-01-11 10:15:00
# 4      2020-01-11 11:15:00
#                ...
# 8779   2021-01-11 02:15:00
# 8780   2021-01-11 03:15:00
# 8781   2021-01-11 04:15:00
# 8782   2021-01-11 05:15:00
# 8783   2021-01-11 06:15:00
# Name: FechaIntervalo, Length: 8784, dtype: datetime64[ns]

# %% [markdown]
# #Ejercicio 04: Timestamp
# * Convierte la columna 'DateTime' la cual tiene un formato de fecha legible a timestamp Unix. Guarda el resultado en una nueva columna
# * Imprime las primeras tres filas de  la columna 'DateTime' y la columna que representa dicha fecha en timestamp Unix

# %%
#Crear la nueva columna timestamp Unix
df['TimeUnix'] = pd.to_datetime(df['DateTime']).astype('int64') // 10**9

#Imrpmir las columnas para observar la fecha original y el timestamp Unix
print(f'Fecha original:',df['DateTime'])
print(f'Timestamp Unix:',df['TimeUnix'])
# Out:
# Fecha original: 0      2020-01-01 00:00:00
# 1      2020-01-01 01:00:00
# 2      2020-01-01 02:00:00
# 3      2020-01-01 03:00:00
# 4      2020-01-01 04:00:00
#                ...
# 8779   2020-12-31 19:00:00
# 8780   2020-12-31 20:00:00
# 8781   2020-12-31 21:00:00
# 8782   2020-12-31 22:00:00
# 8783   2020-12-31 23:00:00
# Name: DateTime, Length: 8784, dtype: datetime64[ns]
# Timestamp Unix: 0       1577836800
# 1       1577840400
# 2       1577844000
# 3       1577847600
# 4       1577851200
#            ...
# 8779    1609441200
# 8780    1609444800
# 8781    1609448400
# 8782    1609452000
# 8783    1609455600
# Name: TimeUnix, Length: 8784, dtype: int64

# %% [markdown]
# #Ejercicio 05: Filtrado de Fechas
#
# * Utiliza la columna 'DateTime' y Filtra aquellas fechas que son mayores a 2020-11-01
# * Imprime el resultado

# %%
#Crear columna filtrada con fechas mayores a 2020-11-01
df_filtrado = df[df['DateTime'] > '2020-11-01']

#Imprimir las fechas filtradas
print(f'Fechas filtradas:',df_filtrado)
# Out:
# Fechas filtradas:                 DateTime  Temperature  Humidity  Wind_Speed  Wind_Direction  \
# 7321 2020-11-01 01:00:00    13.620529        58    6.638072       130.60129
# 7322 2020-11-01 02:00:00    13.980529        40    6.618519       157.61987
# 7323 2020-11-01 03:00:00    13.010529        43    8.209263       164.74487
# 7324 2020-11-01 04:00:00    12.190529        51    7.568566       154.65382
# 7325 2020-11-01 05:00:00    12.510529        59    7.594208       148.57043
# ...                  ...          ...       ...         ...             ...
# 8779 2020-12-31 19:00:00     4.920528        72    4.553680       251.56506
# 8780 2020-12-31 20:00:00     4.990529        74    3.259939       186.34020
# 8781 2020-12-31 21:00:00     4.360529        84   10.587917       252.18112
# 8782 2020-12-31 22:00:00     3.820528        88    8.435069       219.80557
# 8783 2020-12-31 23:00:00     3.170529        89    6.792466       212.00539
#
# ...

# %% [markdown]
# ##Conclusiones
# * Al cargar el dataset lo hicimos sin convertir a datatime la columna DateTime, por lo cual posteriormente usamos `pd.to_datetime` para convertir de tipo de dato cadena a tipo datetime.
# * Podemos extraer componentes de la fecha (año) con `df['DateTime'].dt.year`
# * Realizar suma de intervalos con df['DateTime'] + `pd.Timedelta(days=10, hours= 7, minutes=15)`
# * Filtrado de fechas usando `df[df['DateTime'] > '2020-11-01']`
