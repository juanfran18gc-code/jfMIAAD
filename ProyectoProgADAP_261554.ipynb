# %% [markdown]
# <a href="https://colab.research.google.com/github/juanfran18gc-code/jfMIAAD/blob/Proyecto-261554/ProyectoProgADAP_261554.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Proyecto de Programación para Analítica Descriptiva y Predictiva**
# ## Nombre del Proyecto: [Análisis de Encuesta Nacional de Salud Financiera]
# ## Grupo: [A]
# ## Autor: [Juan Francisco Gámez Cortés]
# ## Matrícula: [261554]
# ## Fecha: [septiembre de 2025]

# %% [markdown]
# # **1. Introducción**
#
# ## - Descripción del problema: ¿Qué queremos analizar o predecir?
# Analizar la información estadística sobre los aspectos que definen la salud financiera de la población de 18 años y más en México
# ## - Objetivo del análisis: ¿Qué impacto tendrá este análisis?
# Esta información es relevante para el desarrollo de política pública e investigaciones sobre el bienestar financiero.
# ## - Fuente de datos: ¿De dónde provienen los datos?
#
# •	INEGI – ENSAFI 2023
# https://www.inegi.org.mx/programas/ensafi/2023/#documentacion

# %% [markdown]
# # **2. Captura y Carga de Datos**
#
# ## - Explicación de la fuente de datos: ¿Cuáles son las fuentes de datos?, ¿Qué formato tienen los datos (CSV, SQL, API, etc.)?,
# El dataset esta compuesto por 4 tablas (TVIVIENDA, THOGAR, TSDEM y TMODULO) en formato CSV
#
# ##¿Cuántas observaciones y variables contiene el dataset?
# TVIVIENDA - 36 columnas, 20201 filas
# THOGAR -55 columnas, 20448 filas
# TSDEM - 25 columnas, 67781 filas
# TMODULO - 253 columnas, 20448 filas
#
# ## - Explicación sobre problemas en la carga de Datos y el Código para la carga de datos desde archivos (bibiotecas, etc.)

# %%
# Montar Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
# Leer el archivo CSV
# La separación por default es coma (,)
dfTV = pd.read_csv('/content/drive/MyDrive/Proyecto/TVIVIENDA.csv')

# Mostrar las primeras 5 filas
#print(df.head())
print(dfTV.info())
#print(df.tail())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20201 entries, 0 to 20200
# Data columns (total 36 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LLAVEVIV  20201 non-null  int64
#  1   P1_1      20201 non-null  int64
#  2   P1_2      20201 non-null  int64
#  3   P1_3      20201 non-null  int64
#  4   P1_4_01   20201 non-null  int64
#  5   P1_4_02   20201 non-null  int64
#  6   P1_4_03   20201 non-null  int64
#  7   P1_4_04   20201 non-null  int64
#  8   P1_4_05   20201 non-null  int64
#  9   P1_4_06   20201 non-null  int64
#  10  P1_4_07   20201 non-null  int64
#  11  P1_4_08   20201 non-null  int64
#  12  P1_4_09   20201 non-null  int64
#  13  P1_4_10   20201 non-null  int64
#  14  P1_5      20201 non-null  int64
#  15  P1_6      13868 non-null  float64
#  16  P1_7      13868 non-null  float64
#  17  P1_8_1    12056 non-null  float64
#  18  P1_8_2    12056 non-null  float64
#  19  P1_8_3    12056 non-null  float64
# ...

# %%
import pandas as pd
# Leer el archivo CSV
# La separación por default es coma (,)
dfTH = pd.read_csv('/content/drive/MyDrive/Proyecto/THOGAR.csv')

# Mostrar las primeras 5 filas
#print(df.head())
print(dfTH.info())
#print(df.tail())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20448 entries, 0 to 20447
# Data columns (total 55 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   LLAVEHOG     20448 non-null  int64
#  1   LLAVEVIV     20448 non-null  int64
#  2   P4_1_1       20448 non-null  int64
#  3   P4_1_2       20448 non-null  int64
#  4   P4_1_3       20448 non-null  int64
#  5   P4_1_4       20448 non-null  int64
#  6   P4_1_5       20448 non-null  int64
#  7   P4_1_6       20448 non-null  int64
#  8   P4_1_7       20448 non-null  int64
#  9   P4_1_8       20448 non-null  int64
#  10  P4_1_9       20448 non-null  int64
#  11  P4_2         20448 non-null  int64
#  12  P4_3         20448 non-null  int64
#  13  FILTRO_S4_1  20448 non-null  int64
#  14  P4_4_1       17341 non-null  float64
#  15  P4_4_2       17341 non-null  float64
#  16  P4_5_1       17341 non-null  float64
#  17  P4_5_2       17341 non-null  float64
# ...

# %%
import pandas as pd
# Leer el archivo CSV
# La separación por default es coma (,)
dfTS = pd.read_csv('/content/drive/MyDrive/Proyecto/TSDEM.csv')

# Mostrar las primeras 5 filas
#print(df.head())
print(dfTS.info())
#print(df.tail())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67781 entries, 0 to 67780
# Data columns (total 25 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LLAVESDE  67781 non-null  int64
#  1   LLAVEVIV  67781 non-null  int64
#  2   LLAVEHOG  67781 non-null  int64
#  3   PAREN     67781 non-null  int64
#  4   SEXO      67781 non-null  int64
#  5   EDAD      67781 non-null  int64
#  6   P3_6_1    3023 non-null   float64
#  7   P3_6_2    3023 non-null   float64
#  8   P3_6_3    48386 non-null  float64
#  9   P3_7      29298 non-null  float64
#  10  NIV       65457 non-null  float64
#  11  GRA       65457 non-null  float64
#  12  P3_9      55787 non-null  float64
#  13  P3_10     22803 non-null  float64
#  14  UPM       67781 non-null  int64
#  15  VIV_SEL   67781 non-null  int64
#  16  HOGAR     67781 non-null  int64
#  17  N_REN     67781 non-null  int64
#  18  ENT       67781 non-null  int64
#  19  MUN       67781 non-null  int64
# ...

# %%
import pandas as pd
# Leer el archivo CSV
# La separación por default es coma (,)
dfTM = pd.read_csv('/content/drive/MyDrive/Proyecto/TMODULO.csv')

# Mostrar las primeras 5 filas
#print(df.head())
print(dfTM.info())
#print(df.tail())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20448 entries, 0 to 20447
# Columns: 253 entries, LLAVEMOD to EST_DIS
# dtypes: float64(83), int64(170)
# memory usage: 39.5 MB
# None

# %% [markdown]
# #**3.Transformación y Preprocesamiento - Data Wrangling**
#
# ## - Identificación de Tipos de Datos
#
#
# ## - Cantidad de Valores nulos
# ##- Explicación sobre cada una de las problemáticas encontradas, las soluciones y el código

# %% [markdown]
# # **4. Análisis Descriptivo de Datos**
#
# ## - Preguntas a responder con el AD
# ## - Explicación de Estadísticas Básicas Aplicadas, Visualización de Datos con Gráficos, y Resumen de las respuestas

# %% [markdown]
# # **5. Análisis Exploratorio de los Datos**
#
# ## - Preguntas a responder
# ## - Estadísticas Empleadas, visualización y Resumen de las respuestas encontradas.

# %% [markdown]
# # **6. Análisis Predictivo**
#
# ## - Preprocesamiento para Análisis Predictivo: Problemas, Técnicas y Código
#
# ## - Modelado Predictivo
# ### - Modelo elegido y parámetros
# ### - Entrenamiento y Evaluación
# ## - Resultados

# %% [markdown]
# # **7. Conclusiones y Trabajos Futuros**
#
# ## - Resumen del trabajo realizado, hallazgos y posibles mejoras
