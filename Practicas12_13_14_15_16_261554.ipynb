# %% [markdown]
# <a href="https://colab.research.google.com/github/juanfran18gc-code/jfMIAAD/blob/04-Semana/Practicas12_13_14_15_16_261554.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Limpieza y Transformación de Datos-Prácticas 12,13,14,15,16
#
# El objetivo de esta actividad es que los estudiantes practiquen los temas vistos de carga de datos, normalización de nombres de columnas, separación y unión de columnas, errores en los tipos de datos. Todo es en un conjunto de datos utilizando Pandas en Python.
#
# Instrucciones:
#
# 1.  Descarga el archivo CSV, miaad-nyc-r-s.csv, proporcionado en esta tarea. También lo puedes encontrar en recursos.
# 2.  Crea un notebook en colab y guarda el archivo csv descargado en tu drive.
# 3.  Agrega secciones en el colab poniendo como título el nombre de la práctica

# %%
#Montar drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Práctica 11: Carga de Datos
# Al final del archivo contiene una línea que dice "Esta es una línea que no deberías cargar". Esta línea es irrelevante por lo tanto al cargar el CSV a un dataframe se debería de ignorar.
#
# * Carga el archivo a un dataframe usando el código necesario para omitir la última fila.
# * Usa df.tail(3) para demostrar que no has cargado la última línea
# * Imprime la cantidad de filas y columnas del dataframe

# %%
import pandas as pd
# Leer el archivo CSV
# La separación por default es coma (,), skipfooter para omitir la última línea del archivo
df = pd.read_csv('/content/drive/MyDrive/Unidad02/miaad-nyc-r-s.csv', skipfooter=1, engine='python')
# Imprimir las últimas 3 filas
print(df.tail(3))
#Imprimir cantidad de filas y columnas
filas, columnas = df.shape
print(f"\nCantidad de filas: ",{filas})
print(f"Cantidad de columnas: ",{columnas})
#df.info()
# Out:
#        Unnamed: 0  BOROUGH NEIGHBORHOOD  \
# 84545        8411        5      WOODROW
# 84546        8412        5      WOODROW
# 84547        8413        5      WOODROW
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 84545  02 TWO FAMILY DWELLINGS                                        1
# 84546  22 STORE BUILDINGS                                             4
# 84547  35 INDOOR PUBLIC AND CULTURAL FACILITIES                       4
#
#        BLOCK  LOT EASE-MENT BUILDING CLASS AT PRESENT                ADDRESS  \
# 84545   7351   60                                  B2       49 PITNEY AVENUE
# 84546   7100   28                                  K6  2730 ARTHUR KILL ROAD
# 84547   7105  679                                  P9      155 CLAY PIT ROAD
#
#        ... RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  \
# 84545  ...                 2                 0            2              4000
# 84546  ...                 0                 7            7            208033
# 84547  ...                 0                 1            1             10796
#
#        GROSS SQUARE FEET YEAR BUILT TAX CLASS AT TIME OF SALE  \
# 84545               1496       1925                         1
# 84546              64117       2001                         4
# 84547               2400       2006                         4
#
#        BUILDING CLASS AT TIME OF SALE  SALE PRICE            SALE DATE
# 84545                              B2      460000  2017-07-05 00:00:00
# 84546                              K6    11693337  2016-12-21 00:00:00
# 84547                              P9       69300  2016-10-27 00:00:00
#
# [3 rows x 22 columns]
#
# Cantidad de filas:  {84548}
# Cantidad de columnas:  {22}

# %% [markdown]
# # Práctica 12: Agregar una columna
# * Imprime los nombres de la columnas del archivo
# * Asegúrate que el nombre de la primera columna debería ser INDEX MIIAD. Si esto no es así, entonces agrega dicho nombre a la columna y vuelve a imprimir los nombres para mostrar el cambio realizado.

# %%
#Imprimir nombre de columnas
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'BOROUGH', 'NEIGHBORHOOD', 'BUILDING CLASS CATEGORY',
#        'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASE-MENT',
#        'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER', 'ZIP CODE',
#        'RESIDENTIAL UNITS', 'COMMERCIAL UNITS', 'TOTAL UNITS',
#        'LAND SQUARE FEET', 'GROSS SQUARE FEET', 'YEAR BUILT',
#        'TAX CLASS AT TIME OF SALE', 'BUILDING CLASS AT TIME OF SALE',
#        'SALE PRICE', 'SALE DATE'],
#       dtype='object')

# %%
#Renombrar la columna Unnamed
df = df.rename(columns={'Unnamed: 0': 'INDEX MIIAD'})
#Imprimir nombre de columnas, modificada la primer columna
print(df.columns)
# Out:
# Index(['INDEX MIIAD', 'BOROUGH', 'NEIGHBORHOOD', 'BUILDING CLASS CATEGORY',
#        'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASE-MENT',
#        'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER', 'ZIP CODE',
#        'RESIDENTIAL UNITS', 'COMMERCIAL UNITS', 'TOTAL UNITS',
#        'LAND SQUARE FEET', 'GROSS SQUARE FEET', 'YEAR BUILT',
#        'TAX CLASS AT TIME OF SALE', 'BUILDING CLASS AT TIME OF SALE',
#        'SALE PRICE', 'SALE DATE'],
#       dtype='object')

# %% [markdown]
# # Práctica 13: Normalización de los nombres de la columna.
# * Normaliza los nombres de ls columnas, los cuales deberán estar en minúsculas. Asimismo, reemplaza los espacios con guion bajo
# * Imprime los nombres de las columnas para demostrar que has realizado la normalización.

# %%
from string import Template
#Cambiar a minusculas y reemplazar espacios con guion bajo
df.columns = df.columns.str.lower().str.strip().str.replace(r"\s+","_", regex=True)
#Imprimir nombre de columnas, modificada la primer columna
print(df.columns)
# Out:
# Index(['index_miiad', 'borough', 'neighborhood', 'building_class_category',
#        'tax_class_at_present', 'block', 'lot', 'ease-ment',
#        'building_class_at_present', 'address', 'apartment_number', 'zip_code',
#        'residential_units', 'commercial_units', 'total_units',
#        'land_square_feet', 'gross_square_feet', 'year_built',
#        'tax_class_at_time_of_sale', 'building_class_at_time_of_sale',
#        'sale_price', 'sale_date'],
#       dtype='object')

# %% [markdown]
# # Práctica 14: Errores en los Tipos de Datos
# * Imprime los tipos de datos de cada columna.
# * Asegúrate que las columnas de SALE PRICE(sale_price), LAND SQUARE FEET (land_square_feet), GROSS SQUARE FEET (gross_square_feet) sean de tipo flotante. Escribe qué tipo de dato tienen asignado. Si no son correctos, realiza el cambio.
# * Imprime de nuevo los tipos de datos para demostrar que has arreglado el problema.

# %%
#Imprimir tipos de datos original
print("Tipos de datos originales:\n", df.dtypes)
# Out:
# Tipos de datos originales:
#  index_miiad                        int64
# borough                            int64
# neighborhood                      object
# building_class_category           object
# tax_class_at_present              object
# block                              int64
# lot                                int64
# ease-ment                         object
# building_class_at_present         object
# address                           object
# apartment_number                  object
# zip_code                           int64
# residential_units                  int64
# commercial_units                   int64
# total_units                        int64
# land_square_feet                  object
# gross_square_feet                 object
# year_built                         int64
# tax_class_at_time_of_sale          int64
# building_class_at_time_of_sale    object
# sale_price                        object
# sale_date                         object
# dtype: object

# %%
#Convertir columnas a tipo flotante
import numpy as np
df['sale_price'] = pd.to_numeric(df['sale_price'], errors='coerce')
df['land_square_feet'] = pd.to_numeric(df['land_square_feet'], errors='coerce')
df['gross_square_feet'] = pd.to_numeric(df['gross_square_feet'], errors='coerce')

#Imprimir tipos de datos modificado
print("Tipos de datos correctos:\n", df.dtypes)
# Out:
# Tipos de datos correctos:
#  index_miiad                         int64
# borough                             int64
# neighborhood                       object
# building_class_category            object
# tax_class_at_present               object
# block                               int64
# lot                                 int64
# ease-ment                          object
# building_class_at_present          object
# address                            object
# apartment_number                   object
# zip_code                            int64
# residential_units                   int64
# commercial_units                    int64
# total_units                         int64
# land_square_feet                  float64
# gross_square_feet                 float64
# year_built                          int64
# tax_class_at_time_of_sale           int64
# building_class_at_time_of_sale     object
# sale_price                        float64
# sale_date                          object
# dtype: object

# %%
#Convertir sale_date a tipo datetime
import numpy as np
df['sale_date'] = pd.to_datetime(df['sale_date'], dayfirst=True, errors='coerce')


#Imprimir tipos de datos modificado
print("Tipos de datos correctos:\n", df.dtypes)
#Imprime las ultimas 3 filas
print(df.tail(3))
# Out:
# Tipos de datos correctos:
#  index_miiad                                int64
# borough                                    int64
# neighborhood                              object
# building_class_category                   object
# tax_class_at_present                      object
# block                                      int64
# lot                                        int64
# ease-ment                                 object
# building_class_at_present                 object
# address                                   object
# apartment_number                          object
# zip_code                                   int64
# residential_units                          int64
# commercial_units                           int64
# total_units                                int64
# land_square_feet                         float64
# gross_square_feet                        float64
# year_built                                 int64
# tax_class_at_time_of_sale                  int64
# building_class_at_time_of_sale            object
# sale_price                               float64
# sale_date                         datetime64[ns]
# dtype: object
#        index_miiad  borough neighborhood  \
# 84545         8411        5      WOODROW
# 84546         8412        5      WOODROW
# 84547         8413        5      WOODROW
#
#                            building_class_category tax_class_at_present  \
# 84545  02 TWO FAMILY DWELLINGS                                        1
# 84546  22 STORE BUILDINGS                                             4
# 84547  35 INDOOR PUBLIC AND CULTURAL FACILITIES                       4
#
#        block  lot ease-ment building_class_at_present                address  \
# 84545   7351   60                                  B2       49 PITNEY AVENUE
# 84546   7100   28                                  K6  2730 ARTHUR KILL ROAD
# 84547   7105  679                                  P9      155 CLAY PIT ROAD
#
#        ... residential_units  commercial_units  total_units  land_square_feet  \
# 84545  ...                 2                 0            2            4000.0
# 84546  ...                 0                 7            7          208033.0
# 84547  ...                 0                 1            1           10796.0
#
#        gross_square_feet  year_built  tax_class_at_time_of_sale  \
# 84545             1496.0        1925                          1
# 84546            64117.0        2001                          4
# 84547             2400.0        2006                          4
#
#        building_class_at_time_of_sale  sale_price  sale_date
# 84545                              B2    460000.0 2017-07-05
# 84546                              K6  11693337.0 2016-12-21
# 84547                              P9     69300.0 2016-10-27
#
# [3 rows x 22 columns]

# %% [markdown]
# # Práctica 15: Genera el diccionario de datos del dataframe preprocesado. Imprime el contenido de dicho diccionario

# %%
#Crear el diccionario de datos con las modificaciones
diccionario_datos = pd.DataFrame({'Nombre de columna': df.columns,
                                  'Tipo de dato': [str(df[col].dtype) for col in df.columns]})
print(f'El nuevo diccionario de datos:\n',diccionario_datos)
# Out:
# El nuevo diccionario de datos:
#                   Nombre de columna    Tipo de dato
# 0                      index_miiad           int64
# 1                          borough           int64
# 2                     neighborhood          object
# 3          building_class_category          object
# 4             tax_class_at_present          object
# 5                            block           int64
# 6                              lot           int64
# 7                        ease-ment          object
# 8        building_class_at_present          object
# 9                          address          object
# 10                apartment_number          object
# 11                        zip_code           int64
# 12               residential_units           int64
# 13                commercial_units           int64
# 14                     total_units           int64
# 15                land_square_feet         float64
# 16               gross_square_feet         float64
# 17                      year_built           int64
# 18       tax_class_at_time_of_sale           int64
# 19  building_class_at_time_of_sale          object
# 20                      sale_price         float64
# 21                       sale_date  datetime64[ns]

# %%
#Guardamos el diccionario de datos
diccionario_datos.to_csv('drive/MyDrive/Unidad02/diccionario_datos.csv', index=False, encoding='utf-8')
